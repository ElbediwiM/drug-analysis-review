# %%
import pandas as pd

# %%
df = pd.read_excel("../raw_data/Data_Set_webmd_6174_Rows_Randomised.xlsx")
df.head()
# Out:
#     Random Number    Age                                          Condition  \
# 0        0.000004  55-64                                         Depression
# 1        0.000008  25-34                                         Depression
# 2        0.000049  35-44                                         Depression
# 3        0.000104  45-54                                         Depression
# 4        0.000140  35-44                                         Depression
# 5        0.000151  45-54                                 Bipolar Depression
# 6        0.000161  25-34                                         Depression
# 7        0.000189  19-24  Depression associated with Bipolar Disorder, A...
# 8        0.000237  45-54                                         Depression
# 9        0.000384  19-24                                 Bipolar Depression
# 10       0.000409  19-24                                         Depression
# ...

# %%
df['Condition'].value_counts()
# Out:
# Condition
# Depression                                                        3764
# Bipolar Depression                                                1563
# Manic-Depression                                                   292
# Additional Medications to Treat Depression                         273
# Anxiousness associated with Depression                             251
# Rapid Cycle Manic-Depression                                        21
# Depression following Delivery of Baby                                4
# insomnia associated with depression                                  3
# Depression associated with Bipolar Disorder, Adjunct Treatment       2
# Name: count, dtype: int64
